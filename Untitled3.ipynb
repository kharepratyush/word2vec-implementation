# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd /content/gdrive/My Drive/Github/
# %cd word2vec-implementation/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Github
# /content/gdrive/My Drive/Github/word2vec-implementation

# %%
# !ls -la
# Out:
# total 5
# drwx------ 2 root root 4096 May 27 21:04 .git
# -rw------- 1 root root    0 May 27 21:14 initial
# -rw------- 1 root root  707 May 27 21:25 Untitled3.ipynb

# %%
# !git add .
# !git commit -m "Testing with Jupyter notebook"
# !git push origin master
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b8aa0c1a3992.(none)')
